# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/IRWADataset/
# Out:
# /content/drive/MyDrive/IRWADataset

# %%
import os
directory = os.getcwd() + '/inverted'

files = os.listdir(directory)
print(files)
# Out:
# ['Doc1.txt', 'Doc2.txt', 'Doc3.txt', 'Doc4.txt']

# %%
def invertedIndex():
 dictionary =dict()
 for file in files:
       with open(os.getcwd()+'/inverted/'+file,'r') as f:
       #print(f)
          words = f.read().lower().split()
       #print(words)

          for word in words:
              if word not in dictionary:
                 dictionary[word] = [file]
              else:
                dictionary[word].append(file)
 return dictionary

# %%
def And_op(list1,list2):
   if((list1) and (list2)):
       return set(list1).intersection(list2)
   else: 
       return
def Not_op(list1,list2):
   if((list1) and (list2)):
       return set(list1).intersection(list2)
   else: 
       return

li = invertedIndex()
#print(li)
for key in li:
      if key == 'schizophrenia':
         list1 = li[key]
         #print('list1',list1)
      if key == 'drug':
         list2 = li[key]
         #print('list2',list2) 
#print(And_op(list1,list2)) 

for key in li:
    if key == 'approach':
         list1 = li[key]      
    if key == 'drug':
         list2 = li[key]
    if key == 'for':
         list3 = li[key]

list4=OR_op()
list5=Not_op()
list6=And_op()
# Out:
# {'Doc2.txt', 'Doc1.txt'}

# %%
from nltk.tokenize import word_tokenize
import nltk 
from nltk.corpus import stopwords
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sw = stopwords.words('english')


quote = "Pythoners are very intelligent and work very pythonly and now they are pythoning their way to success."
tokenized_words=word_tokenize(quote)

#print(tokenized_words)

newlist_without_stop_words = []

for tw in tokenized_words:
  if tw not in sw:
    newlist_without_stop_words.append(tw)
print(newlist_without_stop_words)
# Out:
# ['Pythoners', 'intelligent', 'work', 'pythonly', 'pythoning', 'way', 'success', '.']

# %%
# adding new 2 stop list
new_stop_list = ['intelligent','work']
final_stop_list = new_stop_list + sw

# %%
#stemming
from nltk.stem import PorterStemmer
stemmed_word=[]
stemmer =PorterStemmer()
for i in tokenized_words:
  stemmed_word.append(stemmer,stem(i))

print(stemmed_word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-bbfd8885a5b3> in <module>()
#       4 stemmer =PorterStemmer()
#       5 for i in tokenized_words:
# ----> 6   stemmed_word.append(stemmer,stem(i))
#       7
#       8 print(stemmed_word)
#
# NameError: name 'stem' is not defined
